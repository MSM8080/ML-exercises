# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
link = '/content/drive/MyDrive/Saber ML Course/assignment 5/Copy of breast_cancer.csv'
data = pd
