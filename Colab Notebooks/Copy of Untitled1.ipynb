# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Get the Data

# %%
import pandas as pd

link = '/content/drive/MyDrive/Saber ML Course/assigment 3/breast_cancer.csv'
data = pd.read_csv(link,header=None,encoding='utf-8')
data.tail()
# Out:
#          0  1      2      3      4      5        6        7        8   \
# 565  926424  M  21.56  22.39    142   1479    0.111   0.1159   0.2439
# 566  926682  M  20.13  28.25  131.2   1261   0.0978   0.1034    0.144
# 567  926954  M   16.6  28.08  108.3  858.1  0.08455   0.1023  0.09251
# 568  927241  M   20.6  29.33  140.1   1265   0.1178    0.277   0.3514
# 569   92751  B   7.76  24.54  47.92    181  0.05263  0.04362        0
#
#           9   ...     23     24     25       26       27      28      29  \
# 565   0.1389  ...   26.4  166.1   2027    0.141   0.2113  0.4107  0.2216
# 566  0.09791  ...  38.25    155   1731   0.1166   0.1922  0.3215  0.1628
# 567  0.05302  ...  34.12  126.7   1124   0.1139   0.3094  0.3403  0.1418
# 568    0.152  ...  39.42  184.6   1821    0.165   0.8681  0.9387   0.265
# 569        0  ...  30.37  59.16  268.6  0.08996  0.06444       0       0
#
#          30       31  32
# 565   0.206  0.07115 NaN
# 566  0.2572  0.06637 NaN
# 567  0.2218   0.0782 NaN
# 568  0.4087    0.124 NaN
# 569  0.2871  0.07039 NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # Get features (x) / labels (y)

# %%
import numpy as np
import matplotlib.pyplot as plt

# get labels (y) from data
y = data.iloc[1:,1].values
#y = np.where(y == 'M',1,-1)

# get features (x) from data
x = data.iloc[1:,2:32].values

# %%
y
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'M', 'M', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'B'], dtype=object)

# %%
x
# Out:
# array([['17.99', '10.38', '122.8', ..., '0.2654', '0.4601', '0.1189'],
#        ['20.57', '17.77', '132.9', ..., '0.186', '0.275', '0.08902'],
#        ['19.69', '21.25', '130', ..., '0.243', '0.3613', '0.08758'],
#        ...,
#        ['16.6', '28.08', '108.3', ..., '0.1418', '0.2218', '0.0782'],
#        ['20.6', '29.33', '140.1', ..., '0.265', '0.4087', '0.124'],
#        ['7.76', '24.54', '47.92', ..., '0', '0.2871', '0.07039']],
#       dtype=object)

# %% [markdown]
# # ٍSplit data

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %% [markdown]
# # decision tree

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

dtc = DecisionTreeClassifier(max_depth=6)
dtc.fit(x_train, y_train)
y_pred = dtc.predict(x_test)
print(accuracy_score(y_pred,y_test))
# Out:
# 0.9473684210526315

# %%
plt.figure(figsize=(12,12))
plot_tree(dtc,fontsize=10)
plt.show()

# %% [markdown]
# # Get features (x) / labels (y)

# %%
# get labels (y) from data
y = data.iloc[1:,1].values
#y = np.where(y == 'M',1,-1)

# get features (x) from data
x = data.iloc[1:,2:32].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=50,max_depth=6)
forest.fit(x_train, y_train)
y_pred = dtc.predict(x_test)
print(accuracy_score(y_pred,y_test))
# Out:
# 1.0

# %% [markdown]
# # Get features (x) / labels (y)

# %%
# get labels (y) from data
y = data.iloc[1:,1].values
#y = np.where(y == 'M',1,-1)

# get features (x) from data
x = data.iloc[1:,2:32].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %% [markdown]
# # K-nearest nieghbours

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
y_pred = dtc.predict(x_test)
print(accuracy_score(y_pred,y_test))
# Out:
# 1.0

# %% [markdown]
# # Get features (x) / labels (y)

# %%
# get labels (y) from data
y = data.iloc[1:,1].values
y = np.where(y == 'M',1,-1)

# get features (x) from data
x = data.iloc[1:,2:32].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %% [markdown]
# # Perceptron

# %%
from sklearn.linear_model import Perceptron
ppn = Perceptron(eta0=0.1, max_iter=100)
ppn.fit(x_train, y_train)
y_pred = ppn.predict(x_test)
print(accuracy_score(y_pred,y_test))
# Out:
# 0.9239766081871345

# %% [markdown]
# # Get features (x) / labels (y)

# %%
# get labels (y) from data
y = data.iloc[1:,1].values
y = np.where(y == 'M',1,-1)

# get features (x) from data
x = data.iloc[1:,2:32].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %% [markdown]
# # AdalineGD

# %%
class AdalineGD():

    def __init__(self, eta=0.01, n_iter=50, random_state=1):
        self.eta = eta
        self.n_iter = n_iter
        self.random_state = random_state        

    def fit(self, X, y):
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01, size=1 + X.shape[1])
        self.cost_ = []

        for i in range(self.n_iter):
            net_input = self.net_input(X)  # Z
            output = self.activation(net_input) #W.T X
            errors = (y - output) 


            update = self.eta * X.T.dot(errors) # for all the weights except w0
            self.w_[1:] = self.w_[1:] + update

            update_w0 = self.eta * errors.sum() # for w0
            
            self.w_[0] = self.w_[0] + update_w0
            cost = (errors**2).sum() / 2.0
            self.cost_.append(cost)
        return self

    def net_input(self, X):
        """Calculate net input"""
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def activation(self, X):
        """Compute linear activation"""
        return X

    def predict(self, X):
        """Return class label after unit step"""
        return np.where(self.activation(self.net_input(X)) >= 0.0, 1, -1)

# %%
ada = AdalineGD(eta=0.01,n_iter=100)
ada.fit(x_train,y_train)
y_pred = ada.predict(x_test)
print(  accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-258-fe75617040e9> in <module>
#       1 ada = AdalineGD(eta=0.01,n_iter=100)
# ----> 2 ada.fit(x_train,y_train)
#       3 y_pred = ada.predict(x_test)
#       4 print(  accuracy_score(y_test, y_pred))
#
# <ipython-input-257-ac76a8e4e477> in fit(self, X, y)
#      12
#      13         for i in range(self.n_iter):
# ---> 14             net_input = self.net_input(X)  # Z
#      15             output = self.activation(net_input) #W.T X
#      16             errors = (y - output)
#
# <ipython-input-257-ac76a8e4e477> in net_input(self, X)
#      29     def net_input(self, X):
#      30         """Calculate net input"""
# ---> 31         return np.dot(int(X), self.w_[1:]) + self.w_[0]
#      32
#      33     def activation(self, X):
#
# TypeError: only size-1 arrays can be converted to Python scalars
