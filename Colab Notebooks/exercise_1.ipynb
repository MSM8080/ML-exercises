# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Reading data**

# %%
link = '/kaggle/input/forest-cover-type-kernels-only/train.csv.zip'
data = pd.read_csv(link, encoding='utf-8')
data

# %% [markdown]
# remove nans

# %%
data.isnull().sum()

# %%
data

# %% [markdown]
# Split Data

# %%
from sklearn.model_selection import train_test_split
x = data.iloc[:, 1:-1]
y = data.iloc[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)

# %%
x

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
x_train_std = stdsc.fit_transform(x_train) 
x_test_std = stdsc.transform(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=30,max_depth=30)
forest.fit(x_train_std, y_train)
y_pred = forest.predict(x_test_std)
print(accuracy_score(y_pred,y_test))

# %%
y = data['Cover_Type'].values
data = data.drop('Cover_Type', axis=1)

# %%
data.columns

# %%
data['edl_hydro'] = np.sqrt(data['Horizontal_Distance_To_Hydrology']**2 + data['Vertical_Distance_To_Hydrology']**2)

# %%
data = data.drop('Id', axis=1)

# %%
data.columns

# %%
x = data.iloc[:,:]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
x_train_std = stdsc.fit_transform(x_train) 
x_test_std = stdsc.transform(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=30,max_depth=30)
forest.fit(x_train_std, y_train)
y_pred = forest.predict(x_test_std)
print(accuracy_score(y_pred,y_test))

# %%
data

# %%
data.columns

# %%
data['edl_fire'] = np.sqrt((data['Horizontal_Distance_To_Fire_Points']**2)+(data['Horizontal_Distance_To_Roadways']**2))

# %%
data.columns

# %%
x = data.iloc[:,:]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
x_train_std = stdsc.fit_transform(x_train) 
x_test_std = stdsc.transform(x_test)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=30,max_depth=30)
forest.fit(x_train_std, y_train)
y_pred = forest.predict(x_test_std)
print(accuracy_score(y_pred,y_test))

# %%
data

# %%
data.columns

# %%
data['average_hil'] = (data['Hillshade_9am']+data['Hillshade_Noon']+data['Hillshade_3pm'])/3

# %%
data

# %%
x = data.iloc[:,:]

# %%
x

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
x_train_std = stdsc.fit_transform(x_train) 
x_test_std = stdsc.transform(x_test)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=30,max_depth=30)
forest.fit(x_train_std, y_train)
y_pred = forest.predict(x_test_std)
print(accuracy_score(y_pred,y_test))

# %%
data.columns

# %%
data['Wilderness_Average'] = (data['Wilderness_Area1']+data['Wilderness_Area2']+data['Wilderness_Area3']+data['Wilderness_Area4'])/4

# %%
data.columns

# %%
x = data.iloc[:,:]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
x_train_std = stdsc.fit_transform(x_train) 
x_test_std = stdsc.transform(x_test)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=30,max_depth=30)
forest.fit(x_train_std, y_train)
y_pred = forest.predict(x_test_std)
print(accuracy_score(y_pred,y_test))

# %%
data.columns

# %%
data['Slope*Aspect'] = data['Aspect']*data['Slope']

# %%
data.columns

# %%
data

# %%
data.columns

# %%
data['edl_fire'] = data['edl_fire'].values.astype(int)
data['edl_hydro'] = data['edl_hydro'].values.astype(int)
data['average_hil'] = data['average_hil'].values.astype(int)
data['edl_fire/edl_hydro'] = data['edl_fire/edl_hydro'].values.astype(int)

# %%
data

# %%
x = data.iloc[:,:]
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
x_std = stdsc.fit_transform(x) 
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=30,max_depth=30)
forest.fit(x_std, y)
y_pred = forest.predict(x_std)
print(accuracy_score(y_pred,y))

# %%
link_ts = '../input/forest-cover-type-kernels-only/test.csv.zip'
data_ts = pd.read_csv(link_ts, encoding='utf-8')
data_ts

# %%
id_ts = data_ts.iloc[:,0]

# %%
data_ts['edl_hydro'] = np.sqrt(data_ts['Horizontal_Distance_To_Hydrology']**2 + data_ts['Vertical_Distance_To_Hydrology']**2)
data_ts['edl_fire'] = np.sqrt((data_ts['Horizontal_Distance_To_Fire_Points']**2)+(data_ts['Horizontal_Distance_To_Roadways']**2))
data_ts['average_hil'] = (data_ts['Hillshade_9am']+data_ts['Hillshade_Noon']+data_ts['Hillshade_3pm'])/3
data_ts['Wilderness_Average'] = (data_ts['Wilderness_Area1']+data_ts['Wilderness_Area2']+data_ts['Wilderness_Area3']+data_ts['Wilderness_Area4'])/4
data_ts['Slope*Aspect'] = data_ts['Aspect']*data_ts['Slope']

data_ts['edl_fire'] = data_ts['edl_fire'].values.astype(int)
data_ts['edl_hydro'] = data_ts['edl_hydro'].values.astype(int)
data_ts['average_hil'] = data_ts['average_hil'].values.astype(int)

# %%
data_ts.columns
data_ts = data.drop('Id',axis = 1)

# %%
data.columns
data = data.drop('edl_fire/edl_hydro',axis = 1)

# %%
data.columns

# %%
submit = data_ts.values
submit_std  = stdsc.transform(submit)
y_pred = forest.predict(submit_std)
