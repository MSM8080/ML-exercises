# %%
# connecting drive with colab
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# for 2D plotting and drawing 
import matplotlib.pyplot as plt 
from matplotlib.colors import ListedColormap
# dealing with matrices
import numpy as np
# dealing with files 
import pandas as pd
# 
import os

# %%
class Perceptron(object):
  
  # constactor of class
  #     parameters:
  #       eta = learning rate (step of the line transation)
  #       n_iter = no.repetitions or epoches (no.questions asked on points)
  def __init__(self,eta=0.01, n_iter=50, random_state=1):
    self.eta = eta
    self.n_iter = n_iter
    self.random_state = random_state

  # fitting line function
  #     parameters:
  #       x = matrix of (no.samples * no.features) 
  #       y = vector of dataset original outputs (labels)
  #     variables:
  #       w = vector of updated parameters of equation
  def fit(self,x,y):
    rgen = np.random.RandomState(self.random_state)
    self.w = rgen.normal(loc=0.0, scale=0.01, size=1+x.shape[1])
    # size = 1+x.shape[1] due to W0 (الحد المطلق)
    # x.shape = (c,r) c = no.columns, r = no.raws 
    # loc --> mean, scale --> standard deviation
    self.errors = []
    for i in range(self.n_iter):
      error = 0
      for xi, target in zip(x,y):
        update = self.eta *()
